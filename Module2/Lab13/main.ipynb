# %% [markdown]
# # Before your start:
# - Read the README.md file.
# - Comment as much as you can and use the resources (README.md file).
# - Happy learning!

# %%
# Libraries
import matplotlib.pyplot as plt
import scipy
from scipy.stats import norm
import numpy as np

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions
# #### Step 1: Generate samples and test normal distribution.
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed.
#
# **Hint**: Read the documentation for `scipy.stats.norm.rvs`. The function will help you create the normal random samples.

# %%
# your code here
mean = 50
standard_deviation = 5
sample_size=[10, 50, 500, 5000]

samples = []
for i in sample_size:
    x = scipy.stats.norm.rvs(loc = mean, scale = standard_deviation, size=i)
    samples.append(list(x))
print(samples)
# Out:
# [[57.03269606235374, 51.67597519046535, 50.48332822463071, 48.946449483500615, 49.68099422045019, 49.10758070292852, 55.04606416092056, 55.466656213149584, 44.683616702518634, 50.23034761301199], [54.187881168566754, 51.71054628122713, 45.836111828615834, 50.14130882328955, 50.031748808124114, 48.75552507739855, 52.29557617717861, 56.44125700264264, 45.43264476399849, 48.4386166657366, 52.5154143684861, 47.53911946957257, 52.96792906004968, 44.743289207695014, 44.127025229462795, 50.84398135542931, 42.62046109010969, 42.56534159048344, 49.204239427195745, 53.697803879626, 54.453964849530344, 44.89787238528746, 57.58544217323166, 51.116718676094465, 49.712195646449786, 52.11590936626359, 51.133065406274014, 53.80677046855914, 50.605892149080184, 52.065060126639544, 49.99761379061682, 48.246249061566, 45.33251448302456, 54.58472521031518, 51.88019891518337, 35.21853209723338, 43.89274327265021, 47.490873971555864, 44.79301817053036, 49.96354191633136, 54.432754535586994, 49.03343173733
# ...

# %%
for x in samples:
    print( np.mean(x), np.median(x), np.std(x))
# Out:
# 51.235370857392994 50.356837918821356 3.5058826563607037
# 49.672856474446405 50.08652881570683 4.823048603392529
# 50.15469320501873 50.23251400604279 4.931821432694128
# 49.76680747428236 49.72274858833816 5.036000313105869

# %% [markdown]
# #### Step 2: Plot normal distributions.
#
# To check the shape of the samples you have just created, you can use matplotlib. For example, you can use it to plot a histogram of each sample.
#
# If you did, your outputs would be really similar to the ones below:
#
# ![normal distributions with different sample sizes](../images/ch-1.png)

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
for x in samples:
    plt.hist(x)
    plt.show()

# %%
"""
your comments here
Whit a moore biger sample, it aproximates to normal distribuiton
"""

# %% [markdown]
# #### Bonus: Plot normal distributions.
#
# Even though you still don't know how to use matplotlib, as a bonus challenge, you can try to reproduce the plot above using the samples you have created. This plotting library will be introduced later this week, so don't worry if you don't manage to get the results you want now: you can always come back to solve this challenge later.

# %%
# your code here
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
import seaborn as sns


for x in samples:  
    mean = statistics.mean(x)
    sd = statistics.stdev(x)
    sns.histplot(data=x)
    plt.show()

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# ### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# ### Challenge
#
# We assume that the probability of clicking an advertisement in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# #### Step 1: Create the binomial distribution mentioned above. Store the result in a variable called `dist`.
# **Hint**: use binom from `scipy.stats.binom`. This object takes *n* and *p* as shape parameters, where *n* is the number of independent experiments and *p* the probability of success of the experiment.

# %%
# your code here
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.binom.html

import scipy.stats as stats
from scipy.stats import binom

n = 5
p = 0.15

dist = stats.binom(n,p)

# %% [markdown]
# #### Step 2: Plot the PMF of the distribution.
# To do it, run the code in the cell below.
#
# **Hint**: Your output should look like the one below:
#
# ![binom 10](../images/ch-2.png)

# %%
# run this code
x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %% [markdown]
# #### Step 3: Explain what you observe from the plot above.

# %%
"""
your comments here
Whit the results of smaler sample, we predict the result for a range of observations
"""

# %% [markdown]
# #### Step 4: Now plot PMF with 50, 500, and 5000 visitors.
# To plot the PMF, you can copy the code given above and replace variable `dist` for the name of the variables where you have stored the new binomial objects for 50, 500 and 5000 visitors.

# %%
# your code here

n = 50
p = 0.15

dist = stats.binom(n,p)

x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %%
# your code here

n = 500
p = 0.15

dist = stats.binom(n,p)

x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %%
# your code here

n = 5000
p = 0.15

dist = stats.binom(n,p)

x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()
# Out:
# /Users/edgartome_1/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:67: RuntimeWarning: divide by zero encountered in _binom_pdf
#   return _boost._binom_pdf(x, n, p)

# %% [markdown]
# #### Step 5: What did you notice from the distribution plots? Comment your findings.

# %%
"""
your comments here
The probabilite is less with the incress of visulization (sample)
"""

# %% [markdown]
# # Challenge 3
# #### Step 1: Research the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
"""
your comments here
In statistics, a Poisson distribution is a probability distribution that is used to show how many times 
an event is likely to occur over a specified period. In other words, it is a count distribution. 
Poisson distributions are often used to understand independent events that occur at a constant 
rate within a given interval of time
https://www.investopedia.com/terms/p/poisson-distribution.asp
"""

# %% [markdown]
# #### Step 2: A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# **Hint**: use `scipy.stats.poisson.pmf`.

# %%
# your code here
#https://www.statology.org/poisson-distribution-python/
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html

mu = 300
k = 320

arr = stats.poisson.pmf(k, mu)

arr
# Out:
# 0.011612348610402475

# %% [markdown]
# #### Step 3: What is the probability of getting 60 visits?

# %%
# your code here
mu = 300
k = 60

arr = stats.poisson.pmf(k, mu)

arr
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Step 4: Create a list to store the Poisson distribution probabilities for 0 to 1000 visitors. Store your list in a variable called `arr`.

# %%
# your code here
mu = 300
k = range(0,1000)


arr = stats.poisson.pmf(k, mu)
print(arr)
# Out:
# [5.14820022e-131 1.54446007e-128 2.31669010e-126 2.31669010e-124
#  1.73751758e-122 1.04251055e-120 5.21255273e-119 2.23395117e-117
#  8.37731688e-116 2.79243896e-114 8.37731688e-113 2.28472279e-111
#  5.71180696e-110 1.31810930e-108 2.82451993e-107 5.64903985e-106
#  1.05919497e-104 1.86916760e-103 3.11527933e-102 4.91886210e-101
#  7.37829315e-100 1.05404188e-098 1.43732983e-097 1.87477805e-096
#  2.34347256e-095 2.81216707e-094 3.24480816e-093 3.60534240e-092
#  3.86286685e-091 3.99606916e-090 3.99606916e-089 3.86716370e-088
#  3.62546597e-087 3.29587815e-086 2.90812778e-085 2.49268096e-084
#  2.07723413e-083 1.68424389e-082 1.32966623e-081 1.02282018e-080
#  7.67115132e-080 5.61303755e-079 4.00931254e-078 2.79719479e-077
#  1.90717827e-076 1.27145218e-075 8.29207943e-075 5.29281665e-074
#  3.30801041e-073 2.02531250e-072 1.21518750e-071 7.14816175e-071
#  4.12393947e-070 2.33430536e-069 1.29683631e-068 7.07365261e-068
# ...

# %% [markdown]
# #### Step 5: Plot the probabilities.
# To do it, run the code in the cell below. Your plot should look like the one below:
#
# ![poisson distribution](../images/ch-3.png)

# %%
# run this code
plt.plot(arr)
plt.show()

# %% [markdown]
# # Challenge 4 - Central Limit Theorem
#
# A delivery company needs 35 minutes to deliver a package, with a standard deviation of 8 minutes. Suppose that in one day, they deliver 200 packages.
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: What is the probability that the mean delivery time today is between 30 and 35 minutes?

# %%
# your code here
#https://www.statology.org/normal-cdf-in-python/
from scipy.stats import norm
x1 = 35
x2 = 30
mean = 35
st = 8
y = stats.norm.cdf(x1, mean, st) - stats.norm.cdf(x2, mean, st)
y
# Out:
# 0.23401447095129946

# %% [markdown]
# #### Step 2: What is the probability that in total, it takes more than 115 hours to deliver all 200 packages?

# %%
# your code here
# Have to convert the input in to the same unit as the mean


from scipy.stats import norm
x3 = (115*60)/200
mean = 35
st = 8
y2 = stats.norm.cdf(x3, mean, st)
y2
# Out:
# 0.47508233097075275

# %% [markdown]
# # Challenge 5 - Normal Variables
# The value (in thousands) of the monthly sales of a publishing company follows a normal distribution with a mean equal to 200 and a standard deviation equal to 40.
#
# <div align="center">$X → N(200,40)$</div>
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that the monthly sales are more than 300.

# %%
# your code here
mean = 200
st = 40
x4 = 300

y3 = stats.norm.cdf(x4, mean, st)
y3
# Out:
# 0.9937903346742238

# %% [markdown]
# #### Step 2: Find the probability that the monthly sales fall between 160 and 240.

# %%
# your code here

mean = 200
st = 40
x5 = 160
x6 = 240

y4 = stats.norm.cdf(x6, mean, st) - stats.norm.cdf(x5, mean, st)
y4
# Out:
# 0.6826894921370859

# %% [markdown]
# #### Step 3: Find the probability that the monthly sales do not exceed 150.

# %%
# your code here
#https://towardsdatascience.com/exploring-normal-distribution-with-jupyter-notebook-3645ec2d83f8
mean = 200
st = 40
x7 = 150


y5 = 1 - stats.norm.cdf(x7, mean, st)
print(y5)

#To find the probability of 𝑃(𝑋>4), we can use sf which is called the survival function and it returns 1-cdf
y6 = norm.sf(x7, mean, st)
print(y6)
# Out:
# 0.8943502263331446
# 0.8943502263331446

# %% [markdown]
# #### Step 4: Find the probability that the monthly sales exceed 3000.

# %%
# your code here

mean = 200
st = 40
x8 = 3000


y7 = 1 - stats.norm.cdf(x8, mean, st)
print(y7)
# Out:
# 1.0

# %% [markdown]
# # Challenge 6 - Poisson distribution
# The mean number of violent robberies per month that are registered in a particular barrio is 4.
#
# **Hint**: `stats.poisson.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that in a particular month there is no violent robbery.

# %%
# your code here

# %% [markdown]
# #### Step 2: Find the probability that there are at least 1 robbery in a given month.

# %%
# your code here

# %% [markdown]
# #### Step 3: Find the probability that there are between 2 and 6 (inclusive) robberies in a given month.

# %%
# your code here

# %% [markdown]
# #### Step 4: Find the probability that there are more than 2 robberies in 15 days.

# %%
# your code here
